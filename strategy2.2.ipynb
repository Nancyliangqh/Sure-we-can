# CHK_Close_Mkt   1.707735e+08  1.041513e+08  1.185238e+08  9.907769e+07
# CSCO_Close_Mkt  1.623077e+09  2.150639e+09  1.452025e+09  1.297946e+09
# ECA_Close_Mkt   4.189965e+08  3.337114e+08  2.854277e+08  2.042295e+08
# F_Close_Mkt     4.453043e+08  5.322536e+08  4.939716e+08  5.207056e+08
# FB_Close_Mkt    3.182705e+09  4.361575e+09  5.197576e+09  5.835913e+09
# FCX_Close_Mkt   1.862775e+08  2.833001e+08  1.911423e+08  1.947216e+08
# GE_Close_Mkt    1.415813e+09  1.049640e+09  1.416403e+09  1.160926e+09
# GM_Close_Mkt    3.834222e+08  6.283676e+08  4.176136e+08  4.137381e+08
# INTC_Close_Mkt  1.207044e+09  1.423142e+09  1.546475e+09  1.289232e+09
# LYG_Close_Mkt   1.016176e+08  5.532310e+07  3.470537e+07  3.143140e+07
# MSFT_Close_Mkt  4.145801e+09  4.130838e+09  3.627942e+09  4.684246e+09
# MU_Close_Mkt    9.015544e+08  1.199140e+09  1.003578e+09  1.143170e+09
# ORCL_Close_Mkt  7.860310e+08  1.261841e+09  1.070968e+09  9.672408e+08
# PBR_Close_Mkt   3.900379e+08  2.811885e+08  2.993517e+08  3.369376e+08
# PCG_Close_Mkt   1.370168e+09  1.900942e+09  1.334641e+09  5.313980e+08
# SIRI_Close_Mkt  1.729275e+08  1.963479e+08  2.029217e+08  1.832236e+08
# SWN_Close_Mkt   1.933342e+08  1.363454e+08  1.194839e+08  1.022733e+08
# T_Close_Mkt     9.547647e+08  1.172192e+09  8.762746e+08  8.485162e+08
# VALE_Close_Mkt  3.377339e+08  2.210431e+08  2.465364e+08  2.128512e+08
# X_Close_Mkt     1.245237e+08  1.466101e+08  1.264448e+08  1.720522e+08
#
# Date              2018-11-20
# AAPL_Close_Mkt  1.200370e+10
# ABEV_Close_Mkt  8.066271e+07
# AMD_Close_Mkt   2.110591e+09
# AMRN_Close_Mkt  1.256529e+08
# BAC_Close_Mkt   2.528012e+09
# CHK_Close_Mkt   1.396355e+08
# CSCO_Close_Mkt  1.264877e+09
# ECA_Close_Mkt   2.271322e+08
# F_Close_Mkt     3.185487e+08
# FB_Close_Mkt    5.554048e+09
# FCX_Close_Mkt   2.327363e+08
# GE_Close_Mkt    1.096318e+09
# GM_Close_Mkt    3.625815e+08
# INTC_Close_Mkt  1.383826e+09
# LYG_Close_Mkt   4.433716e+07
# MSFT_Close_Mkt  6.514780e+09
# MU_Close_Mkt    1.398877e+09
# ORCL_Close_Mkt  9.370994e+08
# PBR_Close_Mkt   3.558637e+08
# PCG_Close_Mkt   3.847976e+08
# SIRI_Close_Mkt  1.966744e+08
# SWN_Close_Mkt   1.327155e+08
# T_Close_Mkt     1.217820e+09
# VALE_Close_Mkt  2.784608e+08
# X_Close_Mkt     2.335316e+08
#
# [25 rows x 504 columns]

# %%
# create new data frame named df_returns for strategy2
small = df_small.T #transfer DataFrame
columns = small.columns.tolist()
for i in columns[0:504]:
    index = columns.index(i)
    small[str(i) + '_' + 'returns'] = (small[small.columns[index+1]] - small[small.columns[index]]) / small[small.columns[index]]
    df_returns = small.iloc[:, 504:]# use market values to calculate returns every day
    df_returns.columns = [str(i).split("_")[0] for i in df_returns.columns.tolist()]

# %%
#s = '2011-01-12_returns'
#s.split("_")[0]
# Out:
# '2011-01-12'

# %%
# choose top 5 stocks whose returns are largest to long
# buy2 = []
# for i in range (len(df_returns.columns)):
#     b = df_returns
#     large_returns = b.sort_values([b.columns[i]], ascending=True) # sort each column and choose top 5 stocks every day
#     large_returns
#     ones = np.ones(5, dtype=int)
#     choice = np.array(large_returns.index[0:5]).tolist()
#     c = dict(zip(choice, ones))# create a new dictionary to show stocks longed
#     buy2.append(c)

# %%
# create portfolio_list2 for calculating returns for strategy2
# choose top 5 stocks whose returns are largest to long
def func_portfolio_list2():
    buy2 = []
    for i in range (len(df_returns.columns)):
        b = df_returns
        large_returns = b.sort_values([b.columns[i]],ascending=False) # sort each column and choose top 5 stocks every day
        ones = np.ones(5, dtype=int)
        choice = np.array(large_returns.index[0:5]).tolist()
        c = dict(zip(choice, ones))# create a new dictionary to show stocks longed
        buy2.append(c)
        
    # 'portfolio2' is same as 'buy2' on the first day(buy top 5 stocks whose returns are largest)
        portfolio_list2 = [buy2[0]]
        for i in range(len(buy2) - 1):
            dictMerged = dict(buy2[i], **buy2[i+1]) # merge dictionarys
            for j in buy2[i]:
                if j in buy2[i+1]: # if stock A exists in the both portfolios, we set it to be 0 in the merged portfolio
                    dictMerged[j] = 0 # 0 means no actions
                
                else:            # if stock A exists in the first portfolio but not in the second portfolio, we set it to be -1 in the merged portfolio
                    dictMerged[j] = -1 # -1 means shorting the stock
                
                             # if stock A exists in the second portfolio but not in the first portfolio, we set it to be 1 in the merged portfolio
                             # 1 means longing the stock(same as 'buy')
                             
            portfolio_list2.append(dictMerged)
    return portfolio_list2 # getting portfolio_list2 during the trading days

# %%
# return a dictionary that shows how many shares for each stock should be bought on the first day
def first_day(x, cashpool, stocknum):
    global df_returns
    position = df_returns.columns.tolist().index(x) # get the column index of the date x input
    df_returns = df_returns.sort_values([x],ascending=False) # sort according to date x
    choice = np.array(df_returns.index[0:stocknum]).tolist() # get the largest N(stocknum) stocks of the day
    choice = [i.split('_')[0] for i in choice]

    # get the column name I want to find the close price for each stock on day x
    price = [i.split('_')[0] + "_" + 'Close' for i in choice]

    # find the close price for each stock on day x
    close_price = []
    for i in range(len(price)):
        b = df.loc[x, price[i]]
        close_price.append(b) # get the close price for stocks chosen from df
        invest = cashpool / stocknum
        share = [int(invest / i) for i in close_price] # get the shares for stocks chosen
        buy_dict = dict(zip(choice, share)) # update buy_list for INITIAL day x
    return buy_dict
first_day('2016-11-21',10000,5)
# Out:
# {'X': 69, 'ABEV': 386, 'PCG': 33, 'VALE': 261, 'INTC': 57}

# %%
# position = df_returns.columns.tolist().index('2016-11-21') # get the column index of the date x input
# position
# df_returns = df_returns.sort_values(['2016-11-21'],ascending=False) # sort according to date x
# df_returns
# choice = np.array(df_returns.index[0:5]).tolist()
# choice
# choice = [i.split('_')[0] for i in choice]
# choice
# price_name = [i.split('_')[0] + "_" + 'Close' for i in choice]
# price_name
# close = []
# close
# b = df.loc['2016-11-21', price[1]]
# b
# share = 1000
# Out:
# 5.18

# %%
# def func_portfolio_list2():
    buy2 = []
    for i in range (len(df_returns.columns)):
        b = df_returns
        large_returns = b.sort_values([b.columns[i]],ascending=False) # so
